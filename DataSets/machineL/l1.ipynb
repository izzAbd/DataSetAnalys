# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.scatter([1,2,3,4],[1,8,27,64])
plt.xlabel("saylar")
plt.ylabel("qitmetler")
# Out:
# Text(0, 0.5, 'qitmetler')

# %%
plt.plot([1,2,3,4,5],[1,8,27,64,125])
plt.xlabel("saylar")
plt.ylabel("qitmetler")
# Out:
# Text(0, 0.5, 'qitmetler')
